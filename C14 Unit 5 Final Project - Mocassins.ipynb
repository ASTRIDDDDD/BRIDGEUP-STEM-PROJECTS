# %% [markdown]
# # Unit 5 Anthropology - Final Project

# %% [markdown]
# Exploring the AMNH collections database for mocassins and reporting their color combinations.
#
# Create at least two functions to find the following using Claire Heckel's moccasin data:
# 1. How many color combinations are used on moccasins? How many moccasins have a combination of 3 colors?
# 2. Which color combinations occur most often in our moccasins data (min/max)?
# 3. What are the three most common pairs of motifs on moccasins? What are the least common?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df_moccasins = pd.read_csv("/content/drive/MyDrive/ClairesMoccasinData - Data.csv")

# %%
two_color_combos = pd.read_csv("/content/drive/MyDrive/2_color_combos.txt")

# %%
three_color_combos = pd.read_csv("/content/drive/MyDrive/3_color_combos.txt")

# %%
four_color_combos = pd.read_csv("/content/drive/MyDrive/4_color_combos.txt")

# %%
five_color_combos = pd.read_csv("/content/drive/MyDrive/5_color_combos.txt")

# %%
five_motif_combos = pd.read_csv("/content/drive/MyDrive/5_motif_combos.txt")

# %%
four_motif_combos = pd.read_csv("/content/drive/MyDrive/4_motif_combos.txt")

# %%
three_motif_combos = pd.read_csv("/content/drive/MyDrive/3_motif_combos.txt")

# %%
print(len(two_color_combos))
# Out:
# 594

# %%
print(len(three_color_combos))
# Out:
# 6544

# %%
print(len(four_color_combos))
# Out:
# 52359

# %%
print(len(five_color_combos))
# Out:
# 324631

# %%
594 + 6544 + 52359 + 324631 #color combinations that are use on moccasins
# Out:
# 384128

# %%
two_color_combos.columns
# Out:
# Index(['BLACK', ' TR_CRYSTAL'], dtype='object')
